# %%
a = [10, 20]

# %%
b = [a, 30]

# %%
a.append(b)

# %%
a
# Out:
# [10, 20, [[...], 30]]

# %%
[10, 20, [[...], 30]]
# Out:
# [10, 20, [[Ellipsis], 30]]

# %%
from copy import deepcopy

# %%
c = deepcopy(a)

# %%
c
# Out:
# [10, 20, [[...], 30]]
